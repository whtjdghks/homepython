# %%
import folium
import pandas as pd
import json
import re

# %%
state_geo = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'
# Out:
# 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# %%
df = pd.read_excel("./서울시 교촌치킨 위도경도 데이터.xlsx")
df
# Out:
#     업종          가게이름  평가점수  평가인원  리뷰갯수  \
# 0   치킨   교촌치킨 압구정신사점   1.4    21    10
# 1   치킨    교촌치킨 중곡1호점   3.0    10     4
# 2   치킨  교촌치킨 신대방삼거리점   1.9    16     4
# 3   치킨    교촌치킨 잠실1호점   1.8    20     4
# 4   치킨    교촌치킨 봉천2호점   1.8    19     3
# 5   치킨   교촌치킨 동대문1호점   3.4    10     8
# 6   치킨      교촌치킨 건대점   1.8    21    16
# 7   치킨    교촌치킨 대치1호점   3.2     5     8
# 8   치킨    교촌치킨 신림2호점   2.5    13     3
# 9   치킨    교촌치킨 망원2동점   3.0    18     2
# 10  치킨   교촌치킨 왕십리1호점   2.4    18     7
# 11  치킨      교촌치킨 숙대점   3.8     6    15
# 12  치킨   교촌치킨 압구정신사점   1.4    21    10
# 13  치킨    교촌치킨 중곡1호점   3.0    10     4
# 14  치킨  교촌치킨 신대방삼거리점   1.9    16     4
# 15  치킨    교촌치킨 잠실1호점   1.8    20     4
# 16  치킨    교촌치킨 봉천2호점   1.8    19     3
# 17  치킨   교촌치킨 동대문1호점   3.4    10     8
# 18  치킨      교촌치킨 건대점   1.8    21    16
# 19  치킨    교촌치킨 대치1호점   3.2     5     8
# 20  치킨    교촌치킨 신림2호점   2.5    13     3
# 21  치킨    교촌치킨 망원2동점   3.0    18     2
# 22  치킨    교촌치킨 영등포역점   3.7     6    20
# 23  치킨   교촌치킨 신도림1호점   1.5     8     4
# 24  치킨     교촌치킨 성수역점   2.9    10     3
# 25  치킨    교촌치킨 봉천1호점   5.0     6     0
# 26  치킨      교촌치킨 상암점   1.9    20     7
# 27  치킨    교촌치킨 잠실2호점   2.7    13     8
# 28  치킨      교촌치킨 발산점   1.3     6    14
# 29  치킨      교촌치킨 도화점   2.2    18     4
# 30  치킨     교촌치킨 수유역점   2.7     7     5
# 31  치킨      교촌치킨 녹번점   3.4    10     1
# 32  치킨     교촌치킨 미아역점   3.1     7    14
#
#                                          주소         위도          경도  \
# 0              서울 강남구 언주로172길 29 대성빌딩 1층 전체  37.526763  127.037687
# 1                            서울 광진구 긴고랑로 40  37.557724  127.092035
# 2                       서울 동작구 여의대방로24길 129  37.499303  126.927191
# 3                       서울 송파구 백제고분로7길 9 1층  37.510512  127.079848
# 4                         서울 관악구 남부순환로 1881  37.479222  126.958694
# 5                          서울 종로구 종로 294 2층  37.571207  127.010691
# 6                         서울 광진구 아차산로31길 13  37.541667  127.069380
# 7                            서울 강남구 선릉로 312  37.497500  127.052643
# 24   02-497-1991  매일 12:00 ~ 03:30
# 25   02-882-2999               NaN
# 26   02-309-2500  매일 12:00 ~ 02:00
# 27   02-417-9225  매일 12:00 ~ 24:00
# 28  02-2663-6077  매일 12:00 ~ 24:00
# 29   02-715-9987  매일 11:30 ~ 02:00
# 30   02-903-3693  매일 12:00 ~ 24:00
# 31   02-359-9200               NaN
# 32   02-989-6288  매일 12:00 ~ 24:00
#
#                                              링크주소
# 0      https://place.map.kakao.com/8189461#review
# 1      https://place.map.kakao.com/8195179#review
# 2   https://place.map.kakao.com/1734988749#review
# 3      https://place.map.kakao.com/8662816#review
# 4      https://place.map.kakao.com/8188912#review
# 5     https://place.map.kakao.com/16039118#review
# 6     https://place.map.kakao.com/12531834#review
# 7    https://place.map.kakao.com/245821752#review
# 8     https://place.map.kakao.com/23205946#review
# 9     https://place.map.kakao.com/11280281#review
# 10     https://place.map.kakao.com/8211598#review
# 11    https://place.map.kakao.com/11245716#review
# 12     https://place.map.kakao.com/8189461#review
# 13     https://place.map.kakao.com/8195179#review
# 14  https://place.map.kakao.com/1734988749#review
# 15     https://place.map.kakao.com/8662816#review
# 16     https://place.map.kakao.com/8188912#review
# 17    https://place.map.kakao.com/16039118#review
# 18    https://place.map.kakao.com/12531834#review
# 19   https://place.map.kakao.com/245821752#review
# 20    https://place.map.kakao.com/23205946#review
# 21    https://place.map.kakao.com/11280281#review
# 22  https://place.map.kakao.com/1453931126#review
# 23    https://place.map.kakao.com/16043797#review
# 24    https://place.map.kakao.com/26495623#review
# 25  https://place.map.kakao.com/1619872805#review
# 26    https://place.map.kakao.com/15931676#review
# 27    https://place.map.kakao.com/26416252#review
# 28    https://place.map.kakao.com/21239224#review
# 29    https://place.map.kakao.com/17610680#review
# 30    https://place.map.kakao.com/11038364#review
# 31  https://place.map.kakao.com/2115900161#review
# 32    https://place.map.kakao.com/18914992#review

# %%
df.columns
# Out:
# Index(['업종', '가게이름', '평가점수', '평가인원', '리뷰갯수', '주소', '위도', '경도', '전화', '영업시간',
#        '링크주소'],
#       dtype='object')

# %%
df1 = df['위도'].values
df1
# Out:
# array([37.526763 , 37.5577237, 37.4993033, 37.5105116, 37.4792215,
#        37.5712073, 37.5416671, 37.4974998, 37.4712962, 37.5581472,
#        37.5639775, 37.5449111, 37.526763 , 37.5577237, 37.4993033,
#        37.5105116, 37.4792215, 37.5712073, 37.5416671, 37.4974998,
#        37.4712962, 37.5581472, 37.5177023, 37.5055421, 37.546073 ,
#        37.4818565, 37.5766974, 37.5175312, 37.5574211, 37.5410215,
#        37.6388609, 37.603429 , 37.6215002])

# %%
df1 = df['위도'].values.tolist()
df1
# Out:
# [37.526763,
#  37.5577237,
#  37.4993033,
#  37.5105116,
#  37.4792215,
#  37.5712073,
#  37.5416671,
#  37.4974998,
#  37.4712962,
#  37.5581472,
#  37.5639775,
#  37.5449111,
#  37.526763,
#  37.5577237,
#  37.4993033,
#  37.5105116,
#  37.4792215,
#  37.5712073,
#  37.5416671,
#  37.4974998,
#  37.4712962,
#  37.5581472,
#  37.5177023,
#  37.5055421,
#  37.546073,
#  37.4818565,
#  37.5766974,
#  37.5175312,
#  37.5574211,
#  37.5410215,
#  37.6388609,
#  37.603429,
#  37.6215002]

# %%
df2 = df['경도'].values
df2
# Out:
# array([127.0376871, 127.092035 , 126.9271912, 127.0798478, 126.9586939,
#        127.0106909, 127.0693804, 127.0526427, 126.917945 , 126.9078145,
#        127.0297054, 126.9696855, 127.0376871, 127.092035 , 126.9271912,
#        127.0798478, 126.9586939, 127.0106909, 127.0693804, 127.0526427,
#        126.917945 , 126.9078145, 126.9076995, 126.8828721, 127.0546051,
#        126.9522114, 126.8945347, 127.103575 , 126.8437684, 126.9493516,
#        127.0287584, 126.9257462, 127.0283635])

# %%
df2 = df['경도'].values.tolist()
df2
# Out:
# [127.0376871,
#  127.092035,
#  126.9271912,
#  127.0798478,
#  126.9586939,
#  127.0106909,
#  127.0693804,
#  127.0526427,
#  126.917945,
#  126.9078145,
#  127.0297054,
#  126.9696855,
#  127.0376871,
#  127.092035,
#  126.9271912,
#  127.0798478,
#  126.9586939,
#  127.0106909,
#  127.0693804,
#  127.0526427,
#  126.917945,
#  126.9078145,
#  126.9076995,
#  126.8828721,
#  127.0546051,
#  126.9522114,
#  126.8945347,
#  127.103575,
#  126.8437684,
#  126.9493516,
#  127.0287584,
#  126.9257462,
#  127.0283635]

# %%
m = folium.Map(
    location=df[['위도','경도']]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-d0159ead4cc2> in <module>
# ----> 1 m = folium.Map(
#       2     location=df[['위도','경도']]
#       3 )
#
# ~\anaconda3\lib\site-packages\folium\folium.py in __init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, **kwargs)
#     253             zoom_start = 1
#     254         else:
# --> 255             self.location = validate_location(location)
#     256
#     257         Figure().add_child(self)
#
# ~\anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      42     if isinstance(location, np.ndarray) \
#      43             or (pd is not None and isinstance(location, pd.DataFrame)):
# ---> 44         location = np.squeeze(location).tolist()
#      45     if not hasattr(location, '__len__'):
#      46         raise TypeError('Location should be a sized variable, '
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
# Out:
# <ipython-input-44-67ebe9c084dc>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.int(df1['위도'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-67ebe9c084dc> in <module>
#       1 import numpy as np
#       2
# ----> 3 np.int(df1['위도'])
#
# TypeError: list indices must be integers or slices, not str

# %%
newdf=pd.DataFrame()

# %%
newdf['위도']=df1['위도']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7c70978f31c2> in <module>
# ----> 1 newdf['위도']=df1['위도']
#
# TypeError: list indices must be integers or slices, not str
