# %%
import pandas as pd

FC=pd.read_excel('./DATA/생계데이터.xlsx')
DC=pd.read_excel('./DATA/육계데이터.xlsx')
PC=pd.read_excel('./DATA/부분육데이터.xlsx')

# %%
FC.head()
# Out:
#           일자 요일     대     중     소  병아리  종계노계
# 0 2021-01-02  토  2190  2290  2390  600   450
# 1 2021-01-04  월  2190  2290  2390  600   450
# 2 2021-01-05  화  2190  2290  2390  600   450
# 3 2021-01-06  수  2290  2390  2490  600   450
# 4 2021-01-07  목  2290  2390  2490  600   450

# %%
DC.head()
# Out:
#           일자 요일  5-6호  7-8호  9-10호   11호   12호  13-16호   35호
# 0 2021-11-18  목  3100  2974   2692  2591  2364    2336  2380
# 1 2021-11-17  수  3100  2974   2692  2591  2509    2479  2380
# 2 2021-11-16  화  3291  3133   2846  2738  2654    2621  2380
# 3 2021-11-15  월  3433  3291   3000  2885  2799    2764  2380
# 4 2021-11-13  토  3600  3450   3154  3032  2944    2907  2380

# %%
DC.sort_values(by='일자',ascending=True)
# Out:
#             일자 요일  5-6호  7-8호  9-10호   11호   12호  13-16호   35호
# 261 2021-01-02  토  4433  4244   3923  3768  3524    3479  2080
# 260 2021-01-04  월  4433  4244   3923  3768  3524    3479  2080
# 259 2021-01-05  화  4433  4244   3923  3768  3524    3479  2080
# 258 2021-01-06  수  4600  4402   4077  3915  3669    3621  2080
# 257 2021-01-07  목  4600  4402   4077  3915  3669    3621  2080
# ..         ... ..   ...   ...    ...   ...   ...     ...   ...
# 4   2021-11-13  토  3600  3450   3154  3032  2944    2907  2380
# 3   2021-11-15  월  3433  3291   3000  2885  2799    2764  2380
# 2   2021-11-16  화  3291  3133   2846  2738  2654    2621  2380
# 1   2021-11-17  수  3100  2974   2692  2591  2509    2479  2380
# 0   2021-11-18  목  3100  2974   2692  2591  2364    2336  2380
#
# [262 rows x 9 columns]

# %%
PC.head()
# Out:
#           일자 요일  넓적다리    북채    날개    가슴    안심    정육
# 0 2021-11-18  목  4482  4920  5251  5056  5056  6505
# 1 2021-11-17  수  4731  5196  5548  5340  5340  6880
# 2 2021-11-16  화  4980  5473  5844  5625  5625  7256
# 3 2021-11-15  월  5229  5749  6141  5910  5910  7631
# 4 2021-11-13  토  5478  6025  6438  6194  6194  8006

# %%
PC.sort_values(by='일자',ascending=True)
# Out:
#             일자 요일  넓적다리    북채    날개    가슴    안심    정육
# 261 2021-01-02  토  6473  7130  7626  7333  7333  9507
# 260 2021-01-04  월  6473  7130  7626  7333  7333  9507
# 259 2021-01-05  화  6473  7130  7626  7333  7333  9507
# 258 2021-01-06  수  6722  7406  7923  7618  7618  9883
# 257 2021-01-07  목  6722  7406  7923  7618  7618  9883
# ..         ... ..   ...   ...   ...   ...   ...   ...
# 4   2021-11-13  토  5478  6025  6438  6194  6194  8006
# 3   2021-11-15  월  5229  5749  6141  5910  5910  7631
# 2   2021-11-16  화  4980  5473  5844  5625  5625  7256
# 1   2021-11-17  수  4731  5196  5548  5340  5340  6880
# 0   2021-11-18  목  4482  4920  5251  5056  5056  6505
#
# [262 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import folium as g
import warnings
warnings.filterwarnings('ignore') #경고메시지가 뜹니다~

#from chart_studio import plotly as py
import plotly.offline as plot
import plotly.express as px
import plotly.graph_objs as go
import cufflinks as cf

from plotly.subplots import make_subplots

# %% [markdown]
# # 2021년 1월 부터 11월 까지의 시세 변화(생계)

# %% [markdown]
# ### 전체적으로 하락세

# %%
fig = go.Figure()

# 생계
fig.add_trace(go.Scatter(x=FC['일자'],
                         y=FC['대'],
                    mode='lines', # Line Plot에 마커찍기
                    name='대'))
fig.add_trace(go.Scatter(x=FC['일자'],
                         y=FC['중'],
                    mode='lines', # Line Plot에 마커찍기
                    name='중'))
fig.add_trace(go.Scatter(x=FC['일자'],
                         y=FC['소'],
                    mode='lines', # Line Plot에 마커찍기
                    name='소'))
# 육계
fig.add_trace(go.Scatter(x=DC['일자'],
                         y=DC['대'],
                    mode='lines', # Line Plot에 마커찍기
                    name='대'))
fig.add_trace(go.Scatter(x=DC['일자'],
                         y=DC['중'],
                    mode='lines', # Line Plot에 마커찍기
                    name='중'))
fig.add_trace(go.Scatter(x=DC['일자'],
                         y=DC['소'],
                    mode='lines', # Line Plot에 마커찍기
                    name='소'))
# Out:
# <div>                            <div id="315c1be8-c9d3-4120-8cba-c6f1f391451c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315c1be8-c9d3-4120-8cba-c6f1f391451c")) {                    Plotly.newPlot(                        "315c1be8-c9d3-4120-8cba-c6f1f391451c",                        [{"mode":"lines","name":"\ub300","x":["2021-01-02T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-25T
# ...

# %%
# 가격이 떨어졌다는거는 공급량 즉 출하량이 늘었다고 봐야하나?
